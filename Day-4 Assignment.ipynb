# %%
## Question 1

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
## Question 2

# %%
import numpy as np
n=np.array([1,2,3])
n
p=pd.Series(n,index=['a','b','c'])
p
# Out:
# a    1
# b    2
# c    3
# dtype: int32

# %%
## Question 3

# %%
q=pd.DataFrame({"R.No":[501,502,503],"Name":['A','B','C']})
q
# Out:
#    R.No Name
# 0   501    A
# 1   502    B
# 2   503    C

# %%
index=['a','b','c']
q['Surname']=index
q
# Out:
#    R.No Name Surname
# 0   501    A       a
# 1   502    B       b
# 2   503    C       c

# %%
## Question 4

# %%
import seaborn as sns
sns.get_dataset_names()
df=sns.load_dataset('mpg')
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)

# %%
## Question 5

# %%
print(df['origin'].unique())
# Out:
# ['usa' 'japan' 'europe']

# %%
## Question 6

# %%
df[df['origin']=='usa'].head(20)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# ...
